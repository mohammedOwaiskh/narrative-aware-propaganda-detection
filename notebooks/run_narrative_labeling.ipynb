# %% [markdown]
# # Run narrative_classification.py on Colab T4
# Runtime → Change runtime type → T4 GPU, then run all cells.

# %%
# !pip install -q transformers accelerate bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 20.6 MB/s eta 0:00:00

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
REPO_DIR = '/content/drive/MyDrive/NarraProp/narrative-aware-propaganda-detection'

if not os.path.exists(REPO_DIR):
    # !git clone https://github.com/mohammedOwaiskh/narrative-aware-propaganda-detection.git "{REPO_DIR}"
else:
    # !cd "{REPO_DIR}" && git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 354 bytes | 6.00 KiB/s, done.
# From https://github.com/mohammedOwaiskh/narrative-aware-propaganda-detection
#    8657548..9fb68e3  master     -> origin/master
# Updating 8657548..9fb68e3
# Fast-forward
#  narrative_labeling/narrative_classification.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %cd {REPO_DIR}
# !python src/narrative_labeling/narrative_classification.py
# Out:
# /content/drive/MyDrive/NarraProp/narrative-aware-propaganda-detection
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/NarraProp/narrative-aware-propaganda-detection/narrative_labeling/narrative_classification.py", line 44, in <module>
#     from utils.file_reader import read_frames, read_prompt, read_processed_data, get_project_root
# ModuleNotFoundError: No module named 'utils'
