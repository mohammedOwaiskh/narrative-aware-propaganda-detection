# %% [markdown]
# # Run narrative_classification.py on Colab T4
# Runtime → Change runtime type → T4 GPU, then run all cells.

# %%
# !pip install -q transformers accelerate bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 20.6 MB/s eta 0:00:00

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
REPO_DIR = '/content/drive/MyDrive/NarraProp/narrative-aware-propaganda-detection'

if not os.path.exists(REPO_DIR):
    # !git clone https://github.com/mohammedOwaiskh/narrative-aware-propaganda-detection.git "{REPO_DIR}"
else:
    # !cd "{REPO_DIR}" && git pull
# Out:
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 18 (delta 6), reused 12 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (18/18), 9.91 KiB | 40.00 KiB/s, done.
# From https://github.com/mohammedOwaiskh/narrative-aware-propaganda-detection
#    9fb68e3..c74180a  master     -> origin/master
# Updating 9fb68e3..c74180a
# Fast-forward
#  .idea/narrative-aware-propaganda-detection.iml     |   1 +
#  notebooks/run_narrative_labeling.ipynb             | 272 ++++++++++++---------
#  .../narrative_classification.py                    | 142 +++++------
#  {prompts => src/prompts}/frames.json               |   0
#  .../prompts}/narrative_classification_prompt.txt   |   0
#  .../semeval_data_extractor.py                      |   0
#  {utils => src/utils}/__init__.py                   |   0
#  {utils => src/utils}/file_reader.py                |   5 +-
#  {utils => src/utils}/logger.py                     |   0
#  9 files changed, 231 insertions(+), 189 deletions(-)
#  rename {narrative_labeling => src/narrative_labeling}/narrative_classification.py (82%)
#  rename {prompts => src/prompts}/frames.json (100%)
#  rename {prompts => src/prompts}/narrative_classification_prompt.txt (100%)
#  rename semeval_data_extractor.py => src/semeval_data_extractor.py (100%)
#  rename {utils => src/utils}/__init__.py (100%)
#  rename {utils => src/utils}/file_reader.py (89%)
#  rename {utils => src/utils}/logger.py (100%)

# %%
# %cd {REPO_DIR}
# !pip install -q -e .
# !python -m narrative_labeling.narrative_classification
# Out:
# /content/drive/MyDrive/NarraProp/narrative-aware-propaganda-detection
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/NarraProp/narrative-aware-propaganda-detection/src/narrative_labeling/narrative_classification.py", line 44, in <module>
#     from utils.file_reader import read_frames, read_prompt, read_processed_data, get_project_root
# ModuleNotFoundError: No module named 'utils'
